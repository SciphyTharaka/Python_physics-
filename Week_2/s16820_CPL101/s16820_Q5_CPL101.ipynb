# %% [markdown]
# # Q5

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d  

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 4, 9, 16, 25])

interpolation = interp1d(x, y, kind='linear', fill_value='extrapolate') # Other options for kind: 'nearest', 'quadratic', 'cubic'/ fill_value='extrapolate -If x is outside the known range, don’t crash
print(interpolation)

x1 = np.linspace(0, 5, 100)
y2 = interpolation(x1)

plt.plot(x, y, 'o', label='Data points')
plt.plot(x1, y2, label='Interpolation',color='red')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()
